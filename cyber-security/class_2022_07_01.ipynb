# %%
import pandas
import seaborn

# %%
dataframe = pandas.read_csv("datasets/fraud_detection.csv")

dataframe.sample(5)
# Out:
#          step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2795829   216   PAYMENT  48016.37   C641703677            0.0            0.00
# 25039       8   PAYMENT   4828.31  C2140514154       155362.0       150533.69
# 5579354   393  CASH_OUT  93923.76   C510302780        40487.0            0.00
# 1060431   119   PAYMENT   8852.45  C1726016145        33305.0        24452.55
# 4929418   350     DEBIT   1057.80   C524562706        10193.0         9135.20
#
#            nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 2795829  M414306483            0.00            0.00        0               0
# 25039    M755260123            0.00            0.00        0               0
# 5579354  C108268126        25911.61       119835.36        0               0
# 1060431  M596010603            0.00            0.00        0               0
# 4929418  C209921005        95076.13        96133.93        0               0

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
dataframe.nunique()
# Out:
# step                  743
# type                    5
# amount            5316900
# nameOrig          6353307
# oldbalanceOrg     1845844
# newbalanceOrig    2682586
# nameDest          2722362
# oldbalanceDest    3614697
# newbalanceDest    3555499
# isFraud                 2
# isFlaggedFraud          2
# dtype: int64

# %%
dataframe["type"].unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
dataframe["isFraud"].value_counts()
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
dataframe["isFraud"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
seaborn.pairplot(dataframe.sample(2000), hue="isFraud");

# %%
# LabelEncoder()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 LabelEncoder()
#
# NameError: name 'LabelEncoder' is not defined
