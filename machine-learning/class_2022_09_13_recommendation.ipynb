# %%
import pandas
import numpy
import apyori

# %%
dataset = pandas.read_csv("datasets/store_data.csv")
dataset.sample(20)
# Out:
#                  shrimp          almonds            avocado vegetables mix  \
# 5295              cider             eggs           eggplant            NaN
# 6799             turkey    herb & pepper  whole wheat pasta      spaghetti
# 1765      mineral water             milk              cider           gums
# 7263             shrimp    mineral water               milk      olive oil
# 7239  frozen vegetables    mineral water          meatballs        cereals
# 3499            cookies              NaN                NaN            NaN
# 6909         fresh tuna        spaghetti        french wine           cake
# 3729             pepper    mineral water                NaN            NaN
# 7232      herb & pepper        spaghetti           brownies           mint
# 1915           hot dogs              NaN                NaN            NaN
# 2316  frozen vegetables  parmesan cheese             butter        carrots
# ...

# %%
records = []

for i in range(7501):
    records.append([str(dataset.values[i, j]) for j in range(20) if str(dataset.values[i, j]) != "nan"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [13], line 4
#       1 records = []
#       3 for i in range(7501):
# ----> 4     records.append([str(dataset.values[i, j]) for j in range(20) if str(dataset.values[i, j]) != "nan"])
#
# Cell In [13], line 4, in <listcomp>(.0)
#       1 records = []
#       3 for i in range(7501):
# ----> 4     records.append([str(dataset.values[i, j]) for j in range(20) if str(dataset.values[i, j]) != "nan"])
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:11761, in DataFrame.values(self)
#   11688 """
#   11689 Return a Numpy representation of the DataFrame.
#   11690
#    (...)
#   11758        ['monkey', nan, None]], dtype=object)
#   11759 """
#   11760 self._consolidate_inplace()
# > 11761 return self._mgr.as_array()
#
# ...

# %%
records
